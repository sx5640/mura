# %% [markdown]
# # Result Analysis on VGGNet

# %%
import os
import sys

ROOT_PATH = os.getcwd()
ROOT_PATH = os.path.dirname(ROOT_PATH)
ROOT_PATH = os.path.dirname(ROOT_PATH)
sys.path.append(ROOT_PATH)

# %%
import pandas as pd
import numpy as np

import dataset
import evaluate
import metric
import util
import visualize
import densenet169
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Training

# %% [markdown]
# Let's train a model that takes in all body parts first.
# The model use a 16 layer VGGNet with 3 colour channels. All weights are randomly initialized. It uses Adom optimizer with
#     beta_1=0.9, beta_2=0.999, epsilon=None, amsgrad=False
#
# Image perturbation includes:
#     rotation_range=30,
#     fill_mode="constant",
#     cval=0,
#     horizontal_flip=True
#
# All images are resized to 224*224 px

# %%
# Training Configurations
bpart = "all"
grayscale = False
batch_size = 16
learning_rate = 0.0001
epochs = 40
weight="imagenet"
resize=True
decay=0
reload=True

# %%
model = densenet169.DenseNet169(grayscale=grayscale, weight=weight, resize=resize)
history, model_path, result_path = model.train(batch_size=batch_size, learning_rate=learning_rate, epochs=epochs, bpart=bpart, decay=decay, reload=reload)
# Out:
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 11-16-14
# Epoch 1/40
#  - 1848s - loss: 0.2614 - binary_accuracy: 0.7373 - batch_recall: 0.6963 - global_recall: 0.6816 - global_kappa: 0.4556 - val_loss: 0.2341 - val_binary_accuracy: 0.7876 - val_batch_recall: 0.3815 - val_global_recall: 0.7196 - val_global_kappa: 0.5718
# Epoch 2/40
#  - 986s - loss: 0.2358 - binary_accuracy: 0.7754 - batch_recall: 0.7263 - global_recall: 0.7098 - global_kappa: 0.5317 - val_loss: 0.2483 - val_binary_accuracy: 0.7873 - val_batch_recall: 0.3368 - val_global_recall: 0.6405 - val_global_kappa: 0.5685
# Epoch 3/40
#  - 986s - loss: 0.2290 - binary_accuracy: 0.7876 - batch_recall: 0.7382 - global_recall: 0.7243 - global_kappa: 0.5570 - val_loss: 0.2458 - val_binary_accuracy: 0.7413 - val_batch_recall: 0.4467 - val_global_recall: 0.8484 - val_global_kappa: 0.4858
# Epoch 4/40
#  - 1002s - loss: 0.2229 - binary_accuracy: 0.7962 - batch_recall: 0.7483 - global_recall: 0.7325 - global_kappa: 0.5748 - val_loss: 0.2151 - val_binary_accuracy: 0.8098 - val_batch_recall: 0.3792 - val_global_recall: 0.7216 - val_global_kappa: 0.6160
# Epoch 5/40
#  - 1023s - loss: 0.2157 - binary_accuracy: 0.8023 - batch_recall: 0.7618 - global_recall: 0.7464 - global_kappa: 0.5883 - val_loss: 0.2394 - val_binary_accuracy: 0.7957 - val_batch_recall: 0.3689 - val_global_recall: 0.6961 - val_global_kappa: 0.5872
# Epoch 6/40
#  - 993s - loss: 0.2130 - binary_accuracy: 0.8075 - batch_recall: 0.7670 - global_recall: 0.7532 - global_kappa: 0.5992 - val_loss: 0.2687 - val_binary_accuracy: 0.7779 - val_batch_recall: 0.3212 - val_global_recall: 0.6098 - val_global_kappa: 0.5487
# Epoch 7/40
#  - 1038s - loss: 0.2069 - binary_accuracy: 0.8155 - batch_recall: 0.7772 - global_recall: 0.7639 - global_kappa: 0.6158 - val_loss: 0.2220 - val_binary_accuracy: 0.8201 - val_batch_recall: 0.3858 - val_global_recall: 0.7314 - val_global_kappa: 0.6368
# Epoch 8/40
#  - 1050s - loss: 0.2035 - binary_accuracy: 0.8194 - batch_recall: 0.7813 - global_recall: 0.7661 - global_kappa: 0.6241 - val_loss: 0.2153 - val_binary_accuracy: 0.8048 - val_batch_recall: 0.4218 - val_global_recall: 0.8000 - val_global_kappa: 0.6085
# Epoch 9/40
#  - 1044s - loss: 0.1977 - binary_accuracy: 0.8266 - batch_recall: 0.7926 - global_recall: 0.7788 - global_kappa: 0.6393 - val_loss: 0.2452 - val_binary_accuracy: 0.7976 - val_batch_recall: 0.3649 - val_global_recall: 0.6928 - val_global_kappa: 0.5908
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 10/40
#  - 992s - loss: 0.1756 - binary_accuracy: 0.8499 - batch_recall: 0.8222 - global_recall: 0.8092 - global_kappa: 0.6882 - val_loss: 0.2174 - val_binary_accuracy: 0.8270 - val_batch_recall: 0.3995 - val_global_recall: 0.7595 - val_global_kappa: 0.6513
# Epoch 11/40
#  - 1023s - loss: 0.1639 - binary_accuracy: 0.8606 - batch_recall: 0.8377 - global_recall: 0.8246 - global_kappa: 0.7103 - val_loss: 0.2367 - val_binary_accuracy: 0.8258 - val_batch_recall: 0.3946 - val_global_recall: 0.7516 - val_global_kappa: 0.6486
# Epoch 12/40
#  - 1032s - loss: 0.1597 - binary_accuracy: 0.8660 - batch_recall: 0.8486 - global_recall: 0.8349 - global_kappa: 0.7218 - val_loss: 0.2360 - val_binary_accuracy: 0.8236 - val_batch_recall: 0.3926 - val_global_recall: 0.7477 - val_global_kappa: 0.6441
# Epoch 13/40
#  - 1041s - loss: 0.1540 - binary_accuracy: 0.8713 - batch_recall: 0.8557 - global_recall: 0.8437 - global_kappa: 0.7329 - val_loss: 0.2371 - val_binary_accuracy: 0.8283 - val_batch_recall: 0.4042 - val_global_recall: 0.7686 - val_global_kappa: 0.6540
# Epoch 14/40
#  - 982s - loss: 0.1495 - binary_accuracy: 0.8740 - batch_recall: 0.8573 - global_recall: 0.8474 - global_kappa: 0.7387 - val_loss: 0.2458 - val_binary_accuracy: 0.8251 - val_batch_recall: 0.4058 - val_global_recall: 0.7699 - val_global_kappa: 0.6478
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 15/40
#  - 1035s - loss: 0.1441 - binary_accuracy: 0.8804 - batch_recall: 0.8679 - global_recall: 0.8562 - global_kappa: 0.7521 - val_loss: 0.2460 - val_binary_accuracy: 0.8251 - val_batch_recall: 0.4005 - val_global_recall: 0.7608 - val_global_kappa: 0.6476
# Epoch 16/40
#  - 1018s - loss: 0.1405 - binary_accuracy: 0.8823 - batch_recall: 0.8725 - global_recall: 0.8608 - global_kappa: 0.7560 - val_loss: 0.2444 - val_binary_accuracy: 0.8270 - val_batch_recall: 0.4040 - val_global_recall: 0.7680 - val_global_kappa: 0.6515
# Epoch 17/40
#  - 1001s - loss: 0.1396 - binary_accuracy: 0.8835 - batch_recall: 0.8724 - global_recall: 0.8621 - global_kappa: 0.7585 - val_loss: 0.2508 - val_binary_accuracy: 0.8255 - val_batch_recall: 0.4008 - val_global_recall: 0.7627 - val_global_kappa: 0.6482
# Epoch 18/40
#  - 1042s - loss: 0.1376 - binary_accuracy: 0.8831 - batch_recall: 0.8746 - global_recall: 0.8628 - global_kappa: 0.7577 - val_loss: 0.2526 - val_binary_accuracy: 0.8245 - val_batch_recall: 0.4012 - val_global_recall: 0.7634 - val_global_kappa: 0.6464
# Epoch 19/40
#  - 978s - loss: 0.1379 - binary_accuracy: 0.8858 - batch_recall: 0.8767 - global_recall: 0.8650 - global_kappa: 0.7633 - val_loss: 0.2516 - val_binary_accuracy: 0.8239 - val_batch_recall: 0.4005 - val_global_recall: 0.7621 - val_global_kappa: 0.6451
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 20/40
#  - 1030s - loss: 0.1378 - binary_accuracy: 0.8862 - batch_recall: 0.8765 - global_recall: 0.8649 - global_kappa: 0.7642 - val_loss: 0.2538 - val_binary_accuracy: 0.8239 - val_batch_recall: 0.3992 - val_global_recall: 0.7595 - val_global_kappa: 0.6450
# Epoch 21/40
#  - 984s - loss: 0.1381 - binary_accuracy: 0.8850 - batch_recall: 0.8780 - global_recall: 0.8661 - global_kappa: 0.7620 - val_loss: 0.2535 - val_binary_accuracy: 0.8245 - val_batch_recall: 0.4009 - val_global_recall: 0.7627 - val_global_kappa: 0.6464
# Epoch 22/40
#  - 1000s - loss: 0.1379 - binary_accuracy: 0.8851 - batch_recall: 0.8763 - global_recall: 0.8658 - global_kappa: 0.7620 - val_loss: 0.2539 - val_binary_accuracy: 0.8239 - val_batch_recall: 0.3998 - val_global_recall: 0.7608 - val_global_kappa: 0.6451
# Epoch 23/40
#  - 992s - loss: 0.1386 - binary_accuracy: 0.8847 - batch_recall: 0.8761 - global_recall: 0.8636 - global_kappa: 0.7610 - val_loss: 0.2515 - val_binary_accuracy: 0.8251 - val_batch_recall: 0.4032 - val_global_recall: 0.7667 - val_global_kappa: 0.6477
# Epoch 24/40
#  - 1042s - loss: 0.1372 - binary_accuracy: 0.8866 - batch_recall: 0.8785 - global_recall: 0.8663 - global_kappa: 0.7649 - val_loss: 0.2521 - val_binary_accuracy: 0.8230 - val_batch_recall: 0.4011 - val_global_recall: 0.7634 - val_global_kappa: 0.6433
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 25/40
#  - 1026s - loss: 0.1380 - binary_accuracy: 0.8839 - batch_recall: 0.8769 - global_recall: 0.8628 - global_kappa: 0.7593 - val_loss: 0.2536 - val_binary_accuracy: 0.8245 - val_batch_recall: 0.4008 - val_global_recall: 0.7627 - val_global_kappa: 0.6464
# Epoch 26/40
#  - 1028s - loss: 0.1369 - binary_accuracy: 0.8860 - batch_recall: 0.8776 - global_recall: 0.8659 - global_kappa: 0.7637 - val_loss: 0.2535 - val_binary_accuracy: 0.8258 - val_batch_recall: 0.4011 - val_global_recall: 0.7634 - val_global_kappa: 0.6489
# Epoch 27/40
#  - 994s - loss: 0.1370 - binary_accuracy: 0.8880 - batch_recall: 0.8808 - global_recall: 0.8700 - global_kappa: 0.7680 - val_loss: 0.2528 - val_binary_accuracy: 0.8242 - val_batch_recall: 0.4002 - val_global_recall: 0.7614 - val_global_kappa: 0.6457
# Epoch 28/40
#  - 1007s - loss: 0.1352 - binary_accuracy: 0.8888 - batch_recall: 0.8818 - global_recall: 0.8703 - global_kappa: 0.7696 - val_loss: 0.2565 - val_binary_accuracy: 0.8242 - val_batch_recall: 0.3983 - val_global_recall: 0.7582 - val_global_kappa: 0.6456
# Epoch 29/40
#  - 1028s - loss: 0.1367 - binary_accuracy: 0.8855 - batch_recall: 0.8789 - global_recall: 0.8671 - global_kappa: 0.7630 - val_loss: 0.2513 - val_binary_accuracy: 0.8248 - val_batch_recall: 0.4018 - val_global_recall: 0.7647 - val_global_kappa: 0.6471
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# Epoch 30/40
#  - 1028s - loss: 0.1379 - binary_accuracy: 0.8860 - batch_recall: 0.8779 - global_recall: 0.8663 - global_kappa: 0.7639 - val_loss: 0.2563 - val_binary_accuracy: 0.8258 - val_batch_recall: 0.3986 - val_global_recall: 0.7588 - val_global_kappa: 0.6488
# Epoch 31/40
#  - 1026s - loss: 0.1354 - binary_accuracy: 0.8870 - batch_recall: 0.8765 - global_recall: 0.8661 - global_kappa: 0.7658 - val_loss: 0.2540 - val_binary_accuracy: 0.8251 - val_batch_recall: 0.4018 - val_global_recall: 0.7647 - val_global_kappa: 0.6477
# Epoch 32/40
#  - 1019s - loss: 0.1358 - binary_accuracy: 0.8862 - batch_recall: 0.8765 - global_recall: 0.8675 - global_kappa: 0.7642 - val_loss: 0.2517 - val_binary_accuracy: 0.8236 - val_batch_recall: 0.4021 - val_global_recall: 0.7654 - val_global_kappa: 0.6446
# Epoch 33/40
#  - 986s - loss: 0.1381 - binary_accuracy: 0.8870 - batch_recall: 0.8782 - global_recall: 0.8668 - global_kappa: 0.7659 - val_loss: 0.2540 - val_binary_accuracy: 0.8239 - val_batch_recall: 0.3999 - val_global_recall: 0.7608 - val_global_kappa: 0.6451
# Epoch 34/40
#  - 1006s - loss: 0.1368 - binary_accuracy: 0.8860 - batch_recall: 0.8755 - global_recall: 0.8653 - global_kappa: 0.7639 - val_loss: 0.2586 - val_binary_accuracy: 0.8236 - val_batch_recall: 0.3976 - val_global_recall: 0.7562 - val_global_kappa: 0.6443
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# Epoch 35/40
#  - 1057s - loss: 0.1371 - binary_accuracy: 0.8858 - batch_recall: 0.8774 - global_recall: 0.8672 - global_kappa: 0.7636 - val_loss: 0.2565 - val_binary_accuracy: 0.8233 - val_batch_recall: 0.3986 - val_global_recall: 0.7588 - val_global_kappa: 0.6438
# Epoch 36/40
#  - 1022s - loss: 0.1377 - binary_accuracy: 0.8855 - batch_recall: 0.8750 - global_recall: 0.8649 - global_kappa: 0.7629 - val_loss: 0.2531 - val_binary_accuracy: 0.8245 - val_batch_recall: 0.4014 - val_global_recall: 0.7641 - val_global_kappa: 0.6464
# Epoch 37/40
#  - 1004s - loss: 0.1367 - binary_accuracy: 0.8872 - batch_recall: 0.8772 - global_recall: 0.8658 - global_kappa: 0.7662 - val_loss: 0.2524 - val_binary_accuracy: 0.8242 - val_batch_recall: 0.4021 - val_global_recall: 0.7654 - val_global_kappa: 0.6458
# Epoch 38/40
#  - 1002s - loss: 0.1372 - binary_accuracy: 0.8858 - batch_recall: 0.8770 - global_recall: 0.8660 - global_kappa: 0.7636 - val_loss: 0.2521 - val_binary_accuracy: 0.8242 - val_batch_recall: 0.4011 - val_global_recall: 0.7634 - val_global_kappa: 0.6458
# Epoch 39/40
#  - 1023s - loss: 0.1387 - binary_accuracy: 0.8846 - batch_recall: 0.8771 - global_recall: 0.8647 - global_kappa: 0.7610 - val_loss: 0.2526 - val_binary_accuracy: 0.8255 - val_batch_recall: 0.4011 - val_global_recall: 0.7634 - val_global_kappa: 0.6483
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# Epoch 40/40
#  - 1008s - loss: 0.1372 - binary_accuracy: 0.8841 - batch_recall: 0.8753 - global_recall: 0.8638 - global_kappa: 0.7601 - val_loss: 0.2523 - val_binary_accuracy: 0.8233 - val_batch_recall: 0.4024 - val_global_recall: 0.7660 - val_global_kappa: 0.6440
# ****** Training time: 11:33:32.886546
# ****** Writing Predictions

# %% [markdown]
# *Note:* the model saved has the minimum validation loss, which happens at epoch 4

# %% [markdown]
# #### Training history

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# d:\code\mura\env\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['resize']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
visualize.plot_history(history)

# %% [markdown]
# ## Weighted Cross Entropy

# %% [markdown]
# This implementation used weighted cross entropy loss. In contrast with standard binary cross entropy loss using the same model, the weighted version clearly gave it a boost at the begining of the training, in which the validation kappa started more than 0.1 higher compare to standard. It also gave the model better generalization at the begining of the training, that pushed the validation loss lower than training loss.
#
# However, the weighted loss ends up converging to similar validation kappa compare to standard version, with maximum kappa being only 0.01 higher.
#
# The intuition I got from this is that the weighted cross entropy loss is good at targeting generalization problems, preventing the model to guess the same based on the distribution of the input dataset. But once the model learnt enough about the features, it will converge to the same point as the standard version, as it is still cross entropy loss, and defines the success of the model in the same way.

# %% [markdown]
# ### Metrics

# %%
val_df = pd.read_csv(result_path)
evaluate.evl_result(val_df)
# Out:
# ****** Evaluation per Image
# Accuracy:  0.8098217078511104
# Recall:    0.7215686274509804
# Precision: 0.8584758942457231
# Kappa:     0.6164300519852424
# Contingency Table:
#  1104            182
#   426           1485
# Number of Inputs: 3197
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.8065054211843202
# Recall:    0.7862453531598513
# Precision: 0.7833333333333333
# Kappa:     0.6090301652044602
# Contingency Table:
#   423            117
#   115            544
# Number of Inputs: 1199
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.7973311092577148
# Recall:    0.6133828996282528
# Precision: 0.9041095890410958
# Kappa:     0.5777171620840137
# Contingency Table:
#   330             35
#   208            626
# Number of Inputs: 1199
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8265221017514596
# Recall:    0.7230483271375465
# Precision: 0.8683035714285714
# Kappa:     0.6438101821568026
# Contingency Table:
#   389             59
#   149            602
# Number of Inputs: 1199

# %% [markdown]
# Both averaging or picking the max prediction score from each image of the same study achieves the better overall result. Apperantly having more images helps the model determing whether there is an abnormal.
#
# Interestingly, averaging the prediction score from each image of the same study achieves the best kappa. It does make sense however compare to the other aggregation, since averaging does not favor false positive or false negative.

# %% [markdown]
# #### Let's look at each body part

# %%
for g, df in val_df.groupby(val_df["body_part"]):
    print("****** Evaluation per body part: {} ******".format(g))
    evaluate.evl_result(df)
    print("\n\n")
# Out:
# ****** Evaluation per body part: elbow ******
# ****** Evaluation per Image
# Accuracy:  0.8559139784946237
# Recall:    0.7695652173913043
# Precision: 0.9267015706806283
# Kappa:     0.711273805662388
# Contingency Table:
#   177             14
#    53            221
# Number of Inputs: 465
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.8417721518987342
# Recall:    0.7727272727272727
# Precision: 0.8360655737704918
# Kappa:     0.6712169136007988
# Contingency Table:
#    51             10
#    15             82
# Number of Inputs: 158
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.8227848101265823
# Recall:    0.6212121212121212
# Precision: 0.9318181818181818
# Kappa:     0.6176978914621498
# Contingency Table:
#    41              3
#    25             89
# Number of Inputs: 158
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8670886075949367
# Recall:    0.7272727272727273
# Precision: 0.9411764705882353
# Kappa:     0.7177131189382334
# Contingency Table:
#    48              3
#    18             89
# Number of Inputs: 158
#
#
#
# ****** Evaluation per body part: finger ******
# ****** Evaluation per Image
# Accuracy:  0.7765726681127982
# Recall:    0.6842105263157895
# Precision: 0.8711340206185567
# Kappa:     0.5581538175219836
# Contingency Table:
#   169             25
#    78            189
# Number of Inputs: 461
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.8057142857142857
# Recall:    0.7590361445783133
# Precision: 0.8181818181818182
# Kappa:     0.6090156393744248
# Contingency Table:
#    63             14
#    20             78
# Number of Inputs: 175
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.7542857142857143
# Recall:    0.5421686746987951
# Precision: 0.9
# Kappa:     0.49749582637729534
# Contingency Table:
#    45              5
#    38             87
# Number of Inputs: 175
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8114285714285714
# Recall:    0.7228915662650602
# Precision: 0.8571428571428571
# Kappa:     0.6189376443418011
# Contingency Table:
#    60             10
#    23             82
# Number of Inputs: 175
#
#
#
# ****** Evaluation per body part: forearm ******
# ****** Evaluation per Image
# Accuracy:  0.8372093023255814
# Recall:    0.7350993377483444
# Precision: 0.925
# Kappa:     0.6746376651739426
# Contingency Table:
#   111              9
#    40            141
# Number of Inputs: 301
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.8345864661654135
# Recall:    0.765625
# Precision: 0.875
# Kappa:     0.667197452229299
# Contingency Table:
#    49              7
#    15             62
# Number of Inputs: 133
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.8270676691729323
# Recall:    0.65625
# Precision: 0.9767441860465116
# Kappa:     0.6494786295405061
# Contingency Table:
#    42              1
#    22             68
# Number of Inputs: 133
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8421052631578947
# Recall:    0.703125
# Precision: 0.9574468085106383
# Kappa:     0.6806905224648446
# Contingency Table:
#    45              2
#    19             67
# Number of Inputs: 133
#
#
#
# ****** Evaluation per body part: hand ******
# ****** Evaluation per Image
# Accuracy:  0.7804347826086957
# Recall:    0.5714285714285714
# Precision: 0.84375
# Kappa:     0.5231741861324355
# Contingency Table:
#   108             20
#    81            251
# Number of Inputs: 460
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.7724550898203593
# Recall:    0.6060606060606061
# Precision: 0.7692307692307693
# Kappa:     0.5058402118050145
# Contingency Table:
#    40             12
#    26             89
# Number of Inputs: 167
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.7544910179640718
# Recall:    0.4393939393939394
# Precision: 0.8787878787878788
# Kappa:     0.4377104377104374
# Contingency Table:
#    29              4
#    37             97
# Number of Inputs: 167
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.7964071856287425
# Recall:    0.5606060606060606
# Precision: 0.8809523809523809
# Kappa:     0.5454691002241431
# Contingency Table:
#    37              5
#    29             96
# Number of Inputs: 167
#
#
#
# ****** Evaluation per body part: humerus ******
# ****** Evaluation per Image
# Accuracy:  0.8333333333333334
# Recall:    0.85
# Precision: 0.815068493150685
# Kappa:     0.6667952178943307
# Contingency Table:
#   119             27
#    21            121
# Number of Inputs: 288
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.837037037037037
# Recall:    0.9104477611940298
# Precision: 0.7922077922077922
# Kappa:     0.674413505810129
# Contingency Table:
#    61             16
#     6             52
# Number of Inputs: 135
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.8444444444444444
# Recall:    0.7910447761194029
# Precision: 0.8833333333333333
# Kappa:     0.6886326194398679
# Contingency Table:
#    53              7
#    14             61
# Number of Inputs: 135
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8666666666666667
# Recall:    0.8805970149253731
# Precision: 0.855072463768116
# Kappa:     0.7333772218564842
# Contingency Table:
#    59             10
#     8             58
# Number of Inputs: 135
#
#
#
# ****** Evaluation per body part: shoulder ******
# ****** Evaluation per Image
# Accuracy:  0.7566607460035524
# Recall:    0.6942446043165468
# Precision: 0.7877551020408163
# Kappa:     0.5125356287406225
# Contingency Table:
#   193             52
#    85            233
# Number of Inputs: 563
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.7268041237113402
# Recall:    0.8105263157894737
# Precision: 0.6875
# Kappa:     0.4553448458523146
# Contingency Table:
#    77             35
#    18             64
# Number of Inputs: 194
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.7268041237113402
# Recall:    0.5473684210526316
# Precision: 0.8387096774193549
# Kappa:     0.4495127958025482
# Contingency Table:
#    52             10
#    43             89
# Number of Inputs: 194
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.7319587628865979
# Recall:    0.6736842105263158
# Precision: 0.7529411764705882
# Kappa:     0.4625466169419283
# Contingency Table:
#    64             21
#    31             78
# Number of Inputs: 194
#
#
#
# ****** Evaluation per body part: wrist ******
# ****** Evaluation per Image
# Accuracy:  0.8437025796661608
# Recall:    0.7694915254237288
# Precision: 0.8664122137404581
# Kappa:     0.6805532677908346
# Contingency Table:
#   227             35
#    68            329
# Number of Inputs: 659
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.8396624472573839
# Recall:    0.845360824742268
# Precision: 0.780952380952381
# Kappa:     0.6725567190226872
# Contingency Table:
#    82             23
#    15            117
# Number of Inputs: 237
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.8565400843881856
# Recall:    0.7010309278350515
# Precision: 0.9315068493150684
# Kappa:     0.6915952235150027
# Contingency Table:
#    68              5
#    29            135
# Number of Inputs: 237
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8776371308016878
# Recall:    0.7835051546391752
# Precision: 0.9047619047619048
# Kappa:     0.7416262546520805
# Contingency Table:
#    76              8
#    21            132
# Number of Inputs: 237

# %% [markdown]
# ## Visualization

# %% [markdown]
# #### Attention

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for _ in range(10):
    visualize.plt_attention(model_path, bpart=bpart, grayscale=grayscale)
# Out:
# d:\code\mura\env\lib\site-packages\keras\models.py:282: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)

# %% [markdown]
# #### Activation

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)

# %%
visualize.plt_activation(model_path, layer_idx=-1, max_iter=20000)
# Out:
# d:\code\mura\env\lib\site-packages\keras\models.py:282: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15,910)

# %%
visualize.plt_activation(model_path, layer_idx=util.find_last_conv2d(model.model))

# %% [markdown]
# ## Compare to train a separate model for each body part

# %%
val_df = pd.read_csv("D:\\Code\\mura\\models\\densenet169\\results\\vgg_2018-07-15-2251.csv")

# %%
for bp in val_df["body_part"].unique():
    md = densenet169.DenseNet169(grayscale=grayscale, weight=weight, resize=resize)
    hs, mp, rp = md.train(batch_size=batch_size, learning_rate=learning_rate, epochs=epochs, bpart=bp, decay=decay, verbose=0)
    print("****** Evaluation per body part: {} ******".format(bp))
    evaluate.evl_result(pd.read_csv(rp))
    visualize.plot_history(hs)
    print("\n\n")
# Out:
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 08-56-50
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# d:\code\mura\env\lib\site-packages\keras\callbacks.py:437: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current, self.best):
# d:\code\mura\env\lib\site-packages\keras\callbacks.py:953: RuntimeWarning: invalid value encountered in less
#   self.monitor_op = lambda a, b: np.less(a, b - self.min_delta)
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# ****** Training time: 3:01:07.850373
# ****** Writing Predictions
# ****** Evaluation per body part: wrist ******
# ****** Evaluation per Image
# Accuracy:  0.8603945371775418
# Recall:    0.7796610169491526
# Precision: 0.8949416342412452
# Kappa:     0.7142049043547123
# Contingency Table:
#   230             27
#    65            337
# Number of Inputs: 659
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.8649789029535865
# Recall:    0.865979381443299
# Precision: 0.8155339805825242
# Kappa:     0.7233933912028591
# Contingency Table:
#    84             19
#    13            121
# Number of Inputs: 237
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.8607594936708861
# Recall:    0.7010309278350515
# Precision: 0.9444444444444444
# Kappa:     0.70017251293847
# Contingency Table:
#    68              4
#    29            136
# Number of Inputs: 237
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8945147679324894
# Recall:    0.7938144329896907
# Precision: 0.9390243902439024
# Kappa:     0.7765415802376009
# Contingency Table:
#    77              5
#    20            135
# Number of Inputs: 237
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 12-00-14
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# ****** Training time: 0:54:03.669140
# ****** Writing Predictions
# ****** Evaluation per body part: forearm ******
# ****** Evaluation per Image
# Accuracy:  0.7275747508305648
# Recall:    0.8145695364238411
# Precision: 0.6949152542372882
# Kappa:     0.454830587091929
# Contingency Table:
#   123             54
#    28             96
# Number of Inputs: 301
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.6541353383458647
# Recall:    0.921875
# Precision: 0.59
# Kappa:     0.32112738570794486
# Contingency Table:
#    59             41
#     5             28
# Number of Inputs: 133
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.7593984962406015
# Recall:    0.671875
# Precision: 0.7962962962962963
# Kappa:     0.5153723525392847
# Contingency Table:
#    43             11
#    21             58
# Number of Inputs: 133
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.7669172932330827
# Recall:    0.84375
# Precision: 0.72
# Kappa:     0.5360639135816357
# Contingency Table:
#    54             21
#    10             48
# Number of Inputs: 133
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 12-56-29
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# ****** Training time: 2:17:15.795028
# ****** Writing Predictions
# ****** Evaluation per body part: hand ******
# ****** Evaluation per Image
# Accuracy:  0.7456521739130435
# Recall:    0.5291005291005291
# Precision: 0.78125
# Kappa:     0.44763742353955405
# Contingency Table:
#   100             28
#    89            243
# Number of Inputs: 460
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.7365269461077845
# Recall:    0.6363636363636364
# Precision: 0.6774193548387096
# Kappa:     0.442995755003032
# Contingency Table:
#    42             20
#    24             81
# Number of Inputs: 167
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.7305389221556886
# Recall:    0.36363636363636365
# Precision: 0.8888888888888888
# Kappa:     0.37202306342441693
# Contingency Table:
#    24              3
#    42             98
# Number of Inputs: 167
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.7964071856287425
# Recall:    0.5757575757575758
# Precision: 0.8636363636363636
# Kappa:     0.5480019105238016
# Contingency Table:
#    38              6
#    28             95
# Number of Inputs: 167
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 15-16-26
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# ****** Training time: 0:47:14.666537
# ****** Writing Predictions
# ****** Evaluation per body part: humerus ******
# ****** Evaluation per Image
# Accuracy:  0.8263888888888888
# Recall:    0.8642857142857143
# Precision: 0.7960526315789473
# Kappa:     0.653312788906009
# Contingency Table:
#   121             31
#    19            117
# Number of Inputs: 288
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.8148148148148148
# Recall:    0.9402985074626866
# Precision: 0.75
# Kappa:     0.6302990469930986
# Contingency Table:
#    63             21
#     4             47
# Number of Inputs: 135
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.8296296296296296
# Recall:    0.7611940298507462
# Precision: 0.8793103448275862
# Kappa:     0.6589036581346805
# Contingency Table:
#    51              7
#    16             61
# Number of Inputs: 135
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8666666666666667
# Recall:    0.9253731343283582
# Precision: 0.8266666666666667
# Kappa:     0.733552631578947
# Contingency Table:
#    62             13
#     5             55
# Number of Inputs: 135
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 16-07-05
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# ****** Training time: 4:41:31.134225
# ****** Writing Predictions
# ****** Evaluation per body part: shoulder ******
# ****** Evaluation per Image
# Accuracy:  0.7850799289520426
# Recall:    0.7266187050359713
# Precision: 0.8178137651821862
# Kappa:     0.5695038643099534
# Contingency Table:
#   202             45
#    76            240
# Number of Inputs: 563
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.7577319587628866
# Recall:    0.8631578947368421
# Precision: 0.7068965517241379
# Kappa:     0.5174129353233828
# Contingency Table:
#    82             34
#    13             65
# Number of Inputs: 194
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.7422680412371134
# Recall:    0.5684210526315789
# Precision: 0.8571428571428571
# Kappa:     0.4807836420083501
# Contingency Table:
#    54              9
#    41             90
# Number of Inputs: 194
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.7783505154639175
# Recall:    0.7368421052631579
# Precision: 0.7954545454545454
# Kappa:     0.5558513470343944
# Contingency Table:
#    70             18
#    25             81
# Number of Inputs: 194
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 20-53-26

# %%
for bp in ["finger", "elbow", "wrist"]:
    md = densenet169.DenseNet169(grayscale=grayscale, weight=weight, resize=resize)
    hs, mp, rp = md.train(batch_size=batch_size, learning_rate=learning_rate, epochs=epochs, bpart=bp, decay=decay, verbose=0)
    print("****** Evaluation per body part: {} ******".format(bp))
    evaluate.evl_result(pd.read_csv(rp))
    visualize.plot_history(hs)
    print("\n\n")
# Out:
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 08-38-24
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# ****** Training time: 1:35:47.356036
# ****** Writing Predictions
# ****** Evaluation per body part: finger ******
# ****** Evaluation per Image
# Accuracy:  0.720173535791757
# Recall:    0.757085020242915
# Precision: 0.73046875
# Kappa:     0.4358796801335621
# Contingency Table:
#   187             69
#    60            145
# Number of Inputs: 461
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.7028571428571428
# Recall:    0.8313253012048193
# Precision: 0.6448598130841121
# Kappa:     0.4124483471074379
# Contingency Table:
#    69             38
#    14             54
# Number of Inputs: 175
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.7314285714285714
# Recall:    0.6144578313253012
# Precision: 0.7727272727272727
# Kappa:     0.45598253852768017
# Contingency Table:
#    51             15
#    32             77
# Number of Inputs: 175
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.7314285714285714
# Recall:    0.7831325301204819
# Precision: 0.6914893617021277
# Kappa:     0.4649014377724284
# Contingency Table:
#    65             29
#    18             63
# Number of Inputs: 175
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 10-15-57
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# d:\code\mura\env\lib\site-packages\keras\callbacks.py:437: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current, self.best):
# d:\code\mura\env\lib\site-packages\keras\callbacks.py:953: RuntimeWarning: invalid value encountered in less
#   self.monitor_op = lambda a, b: np.less(a, b - self.min_delta)
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# ****** Training time: 1:51:57.810261
# ****** Writing Predictions
# ****** Evaluation per body part: elbow ******
# ****** Evaluation per Image
# Accuracy:  0.8451612903225807
# Recall:    0.7913043478260869
# Precision: 0.883495145631068
# Kappa:     0.6899425819596219
# Contingency Table:
#   182             24
#    48            211
# Number of Inputs: 465
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.810126582278481
# Recall:    0.8181818181818182
# Precision: 0.75
# Kappa:     0.6146341463414631
# Contingency Table:
#    54             18
#    12             74
# Number of Inputs: 158
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.8291139240506329
# Recall:    0.6212121212121212
# Precision: 0.9534883720930233
# Kappa:     0.6305213926901088
# Contingency Table:
#    41              2
#    25             90
# Number of Inputs: 158
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8607594936708861
# Recall:    0.7727272727272727
# Precision: 0.8793103448275862
# Kappa:     0.7087801608579086
# Contingency Table:
#    51              7
#    15             85
# Number of Inputs: 158
# ****** Building Model
# ****** Preparing Input
# ****** Preparing Training Image Generator
# ****** Loading Validation Inputs
# ****** Starting Training: 12-10-14
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
# ****** Training time: 3:50:58.904365
# ****** Writing Predictions
# ****** Evaluation per body part: wrist ******
# ****** Evaluation per Image
# Accuracy:  0.8391502276176024
# Recall:    0.7593220338983051
# Precision: 0.8648648648648649
# Kappa:     0.6709284139516474
# Contingency Table:
#   224             35
#    71            329
# Number of Inputs: 659
# ****** Evaluation per Study Using Highest Score
# Accuracy:  0.8438818565400844
# Recall:    0.865979381443299
# Precision: 0.7777777777777778
# Kappa:     0.6826620345239385
# Contingency Table:
#    84             24
#    13            116
# Number of Inputs: 237
# ****** Evaluation per Study Using Lowest Score
# Accuracy:  0.8481012658227848
# Recall:    0.6701030927835051
# Precision: 0.9420289855072463
# Kappa:     0.6712898751733699
# Contingency Table:
#    65              4
#    32            136
# Number of Inputs: 237
# ****** Evaluation per Study Using Average Score
# Accuracy:  0.8818565400843882
# Recall:    0.7938144329896907
# Precision: 0.9058823529411765
# Kappa:     0.7509382975529196
# Contingency Table:
#    77              8
#    20            132
# Number of Inputs: 237

# %% [markdown]
# ## Training all body parts together vs Training each body part separately

# %% [markdown]
# From the above result, it is clear that for all body parts, training together yeilds better result than doing so separately.
#
# However it is interesting to see for each body part, how validation loss moves relative to decrease in training loss. For all body parts, validation loss tends to stablize after 5 epoches, but after that, some tends to stay flat(e.g. humerus and forearm) while others tends to go upward(e.g. shoulder). It shows that different body parts suffers differently from the overfitting problem.
